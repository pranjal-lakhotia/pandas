# %% [markdown]
# <a href="https://colab.research.google.com/github/pranjal-lakhotia/pandas/blob/main/MPG_cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv).

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv')

# %% [markdown]
#    ### Step 3. Assign each to a variable called cars1 and cars2

# %%
cars1 = df1
cars2 = df2

# %%
cars1.head(10)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
# 5  15.0          8           429        198    4341          10.0     70
# 6  14.0          8           454        220    4354           9.0     70
# 7  14.0          8           440        215    4312           8.5     70
# 8  14.0          8           455        225    4425          10.0     70
# 9  15.0          8           390        190    3850           8.5     70
#
#    origin                        car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0       1  chevrolet chevelle malibu         NaN          NaN          NaN
# ...

# %%
cars2.head(10)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  33.0          4            91         53    1795          17.4     76
# 1  20.0          6           225        100    3651          17.7     76
# 2  18.0          6           250         78    3574          21.0     76
# 3  18.5          6           250        110    3645          16.2     76
# 4  17.5          6           258         95    3193          17.8     76
# 5  29.5          4            97         71    1825          12.2     76
# 6  32.0          4            85         70    1990          17.0     76
# 7  28.0          4            97         75    2155          16.4     76
# 8  26.5          4           140         72    2565          13.6     76
# 9  20.0          4           130        102    3150          15.7     76
#
#    origin                 car
# 0       3         honda civic
# 1       1      dodge aspen se
# 2       1   ford granada ghia
# 3       1  pontiac ventura sj
# ...

# %% [markdown]
# ### Step 4. Oops, it seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1 = cars1.drop(cars1.iloc[:, 9 :] , axis = 1)

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
cars1.shape
# Out:
# (198, 9)

# %%
cars2.shape
# Out:
# (200, 9)

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars = cars1.append(cars2)

# %%
cars.head(10)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
# 5  15.0          8           429        198    4341          10.0     70
# 6  14.0          8           454        220    4354           9.0     70
# 7  14.0          8           440        215    4312           8.5     70
# 8  14.0          8           455        225    4425          10.0     70
# 9  15.0          8           390        190    3850           8.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# ...

# %% [markdown]
# ### Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
import random

# %%
new_owners = np.random.randint(15000,high = 73001,size = cars.shape[0],dtype = 'I')

# %%
new_owners
# Out:
# array([27354, 42421, 31665, 19075, 49096, 45393, 19591, 50610, 65031,
#        62265, 51172, 26840, 30145, 42539, 27107, 33306, 18252, 24473,
#        66454, 59384, 37505, 38073, 50384, 40916, 60127, 17463, 26677,
#        35294, 41208, 71294, 21266, 21185, 46199, 62245, 16862, 33161,
#        62964, 59709, 35976, 68420, 30397, 38717, 32607, 32569, 53682,
#        37094, 30612, 48256, 51687, 48343, 33687, 17253, 43509, 33623,
#        25452, 23243, 44335, 46102, 71418, 53399, 19599, 62372, 51402,
#        69093, 34545, 42343, 32011, 64559, 51988, 54255, 16827, 54433,
#        16761, 53300, 26504, 54033, 44754, 69115, 22417, 29146, 28588,
#        36371, 21149, 27507, 19100, 42094, 25321, 21250, 19387, 71490,
#        54539, 57308, 62845, 55074, 68143, 27467, 42446, 51817, 23488,
#        32656, 15091, 61973, 31209, 23434, 27525, 20483, 47818, 61952,
#        65427, 39883, 66470, 24492, 64231, 51084, 67037, 52562, 57099,
# ...

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars['owners'] = new_owners

# %%
cars.tail(10)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 190  26.0          4           156         92    2585          14.5     82
# 191  22.0          6           232        112    2835          14.7     82
# 192  32.0          4           144         96    2665          13.9     82
# 193  36.0          4           135         84    2370          13.0     82
# 194  27.0          4           151         90    2950          17.3     82
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                         car  owner  owners
# 190       1  chrysler lebaron medallion  69390   64422
# ...
